# %%
# rock paper and sicssor
print("enter r for ROCK\tp for PAPER\ts for sicssor")
player1=input("enter player1 choice : ")
player2=input('enter player2 choice : ')
if (player1=='r' and player2=='s') or (player1=='p' and player2=='r') or (player1=='s' and player2=='p'):
    print('player1 wins')
elif (player1==player2):
    print('tie')
else:
    print('player2 wins')
# Out:
# enter r for ROCK	p for PAPER	s for sicssor
# enter player1 choice : r
# enter player2 choice : s
# player1 wins

# %%
#snake and ladder
import random
red=0
bule=0
while True:
    player1=random.randint(1,6)
    player2=random.randint(1,6)
    if red>=100:
        print("kasi wins")
        break
    elif bule>=100:
        print("vamsi wins")
        break
    red=red+player1
    bule=bule+player2
    print('player1 : ',red)
    print('player2 : ',bule)
    if red==1: red=38
    if bule==1: bule=38
    if red==4: red=14
    if bule==4: bule=14
    if red==8: red=30
    if bule==8: bule=38
    if red==28: red=76
    if bule==28: bule=76
    if red==21: red=42
    if bule==21: bule=42
    if red==52: red=67
    if bule==52: bule=67
    if red==71: red=92
    if bule==71: bule=92
    if red==80: red=99
    if bule==80: bule=99
    if red==36: red=6
    if bule==36: bule=6
    if red==32: red=10
    if bule==32: bule=10
    if red==48: red=26
    if bule==48: bule=26
    if red==62: red=18
    if bule==62: bule=18
    if red==88: red=24
    if bule==88: bule=24
    if red==95: red=56
    if bule==95: bule=56
    if red==97: red=78
    if bule==97: bule=78
# Out:
# player1 :  1
# player2 :  4
# player1 :  42
# player2 :  16
# player1 :  43
# player2 :  17
# player1 :  46
# player2 :  18
# player1 :  49
# player2 :  20
# player1 :  55
# player2 :  24
# player1 :  57
# player2 :  30
# player1 :  59
# player2 :  36
# player1 :  60
# player2 :  9
# player1 :  63
# player2 :  15
# player1 :  65
# player2 :  21
# player1 :  71
# player2 :  43
# player1 :  94
# player2 :  46
# player1 :  95
# player2 :  48
# player1 :  59
# player2 :  29
# player1 :  64
# player2 :  33
# player1 :  67
# player2 :  36
# player1 :  72
# player2 :  8
# player1 :  78
# player2 :  44
# player1 :  82
# player2 :  49
# player1 :  86
# player2 :  50
# player1 :  87
# player2 :  55
# player1 :  90
# player2 :  61
# player1 :  91
# player2 :  63
# player1 :  93
# player2 :  65
# player1 :  99
# player2 :  66
# player1 :  103
# player2 :  69
# kasi wins
