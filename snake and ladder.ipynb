# %%
#WITH OUT PLAYERS DESICION

# %%
import random

def change(red2,bule2):
    y={1:38,4:14,8:30,28:76,21:42,52:67,71:92,80:99,36:6,32:10,48:26,62:18,88:24,95:56,97:78}
    list1=list(y.keys())
    list2=list(y.values())
    for i in range(len(list1)):
        if red2==list1[i]:
            red1=list2[i]
            if red1>red2: print("player1 got a ladder..... jump from {} to {}".format(red2,red1))
            else: print("player1 got a snake..... go from {} to {}".format(red2,red1))
            return red1,bule2
        if bule2==list1[i]:
            bule1=list2[i]
            if bule1>bule2: print("player2 got a ladder..... jump from {} to {}".format(bule2,bule1))
            else: print("player2 got a snake..... go from {} to {}".format(bule2,bule1))
            return red2,bule1
    return red2,bule2
red=0
bule=0
bule3=0
red3=0
keyr=''
keyb=''
while True:
    while True:
        play1=random.randint(1,6)
        print('player1-',play1)
        if play1==6 and red==0: keyr='start'
        elif play1==6 and red>0: keyr='repeat'
        elif play1>0 and red3>0: keyr='continue'
        elif play1>0 and red==0: break
        if red>=100: break
        if keyr=='start':
            print('congragulations player1 started the game')
            red3+=1
            continue
        if keyr=='continue': 
            red=red+play1
            break
        if keyr=='repeat':
            print("congragulations player1 rolled 6,roll again")
            red=red+play1
            continue
    while True:
        play2=random.randint(1,6)
        print('player2-',play2)
        if play2==6 and bule==0: keyb='start'
        elif play2==6 and bule>0: keyb='repeat'
        elif play2>0 and bule3>0: keyb='continue'
        elif play2>0 and bule==0: break
        if bule>=100: break
        if keyb=='start':
            print('congragulations player2 started the game')
            bule3+=1
            continue
        if keyb=='continue': 
            bule=bule+play2
            break
        if keyb=='repeat':
            print("congragulations player2 rolled 6,roll again")
            bule=bule+play1
            continue
    a=change(red,bule)
    print(a)
    red=a[0]
    bule=a[1]
    print('player1-{},player2-{}'.format(red,bule))
    if red>=100:
        print("player1 wins")
        break
    if bule>=100:
        print("player2 wins")
        break

# %%
#WITH PLAYERS DESICION

# %%
import random

def change(red2,bule2):
    y={1:38,4:14,8:30,28:76,21:42,52:67,71:92,80:99,36:6,32:10,48:26,62:18,88:24,95:56,97:78}
    list1=list(y.keys())
    list2=list(y.values())
    for i in range(len(list1)):
        if red2==list1[i]:
            red1=list2[i]
            return red1,bule2
        if bule2==list1[i]:
            bule1=list2[i]
            return red2,bule1
    return red2,bule2
red=0
bule=0
red4=0
bule4=0
keyr=''
keyb=''
while True:
    while True:
        p1=input('player1 type roll to play: ')
        if p1=='roll':
            play1=random.randint(1,6)
            print('player1-',play1)
            if play1==6 and red==0: keyr='start'
            elif play1==6 and red>0: keyr='repeat'
            elif play1>0 and red4>0: keyr='continue'
            elif play1>0 and red==0: break
            if red>=100: break
        else:
            print('player2 wins')
            play1='not'
            break
        if keyr=='start':
            print('congragulations player1 started the game')
            red4+=1
            continue
        if keyr=='continue': 
            red=red+play1
            break
        if keyr=='repeat':
            print("congragulations player1 rolled 6,roll again")
            red=red+play1
            continue
    while True:
        if play1=='not' : break
        p2=input('player2 type roll to play: ')
        if p2=='roll':
            play2=random.randint(1,6)
            print('player2-',play2)
            if play2==6 and bule==0: keyb='start'
            elif play2==6 and bule>0: keyb='repeat'
            elif play2>0 and bule4>0: keyb='continue'
            elif play2>0 and bule==0: break
            if bule>=100: break
        else:
            print('player1 wins')
            play2='not'
            break
        if keyb=='start':
            print('congragulations player2 started the game')
            bule4+=1
            continue
        if keyb=='continue': 
            bule=bule+play2
            break
        if keyb=='repeat':
            print("congragulations player2 rolled 6,roll again")
            bule=bule+play1
            continue
    a=change(red,bule)
    red=a[0]
    bule=a[1]
    if play1=='not' or play2=='not' : break
    print('player1-{},player2-{}'.format(red,bule))
    if red>=100:
        print("player1 wins")
        break
    if bule>=100:
        print("player2 wins")
        break
